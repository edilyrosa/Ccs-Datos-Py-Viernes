# %% [markdown]
# <a href="https://colab.research.google.com/github/edilyrosa/Ccs-Datos-Py-Viernes/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Analisis explotarorio de la data.**

# %%
import pandas as pd

datos = {
    "propietario": ["Juan Pérez", "María López", "Carlos Gómez", "Ana Rodríguez", "Luis Martínez", "Laura Pérez", "Pablo Ruiz", "Marta Gutiérrez", "Manuel González", "Sofía Díaz", "Laura Martínez", "Carlos Vargas"],
    "metros": [200, None, 500, None, 300, None, 400, None, 600, None, 250, None],
    "propiedad_ocupada": ["S", "S", "N", "S", "S", "S", "S", "N", "S", "S", "S", "S"],
    "num_cuartos": [3, 2, 4, 1, 5, 3, 4, 2, 6, 3, 4, 2],
    "tipo_prop": ["Casa", "Apartamento", "Casa", "Apartamento", "Casa", "Apartamento", "Casa", "Apartamento", "Casa", "Apartamento", "Casa", "Apartamento"],
    "ubicacion": ["Alajuela", "San José", "Cartago", "Heredia", "Guanacaste", "Puntarenas", "San José", "Cartago", "Limón", "Alajuela", "Heredia", "Alajuela"],
    "año_construccion": [1995, 2010, 1980, 2015, 2005, 2018, 2000, 1990, 2008, 2012, 2007, 2019],
    "valor_prop": ["$250,000", "$180,000", "$400,000", "$120,000", "$320,000", "$200,000", "$350,000", "$150,000", "$450,000", "$220,000", "$280,000", "$130,000"],
    "num_baños": [2, 1, 3, 1, None, 1.5, 2.5, 1.5, 3.5, 2, None, 1],
    "estado_prop": ["Buen estado", "Buen estado", "Necesita reparaciones", "Buen estado", "Buen estado", "Buen estado", "Buen estado", "Necesita reparaciones", "Buen estado", "Buen estado", "Buen estado", "Nuevo"],
    "tipo_construccion": ["Tradicional", "Moderna", "Tradicional", "Moderna", "Tradicional", "Moderna", "Tradicional", "Tradicional", "Moderna", "Moderna", "Tradicional", "Moderna"],
    "servicios_disp": ["Garaje", "Gimnasio", "Jardín", "Estacionamiento", "Garaje", "Piscina", "Terraza", "Estacionamiento", "Piscina", "Estacionamiento", "Terraza", "Balcón"],
    "comodidades": ["Terraza", "Balcón", "Chimenea", "Balcón", "Terraza", "Vista al parque", "Chimenea", "Balcón", "Terraza", "Balcón", "Patio", "Vista a la ciudad"],
    "num_garajes": [2, 1, 3, 1, 2, None, 2, 1, 3, 1, None, 1]
}

df = pd.DataFrame(datos)
display('💡LOS PRIMEROS 5 REGISTROS')
display(df.head())

display('💡DIMENCION DEL DF: FILAS, COLUMNAS')
display(df.shape)

display('💡tabla de: Columna - sumatoria de valores unicos')
display(df.nunique())

display('💡 Tabla de: Columna - valores non-null - TDD')
display(df.info())

display('💡tabla de info faltante: columna - sumatoria de valores null en esa columna, esta es la diferencia de info()')
display(df.isnull().sum())
#nota: info() y isnull() complementarias
display('💡tabla: Estadistica descriptiva para cada columna NUEMTICA del df:mean, max, min, std, 25%...')
display(df.describe())
# Out:
# '💡LOS PRIMEROS 5 REGISTROS'
#      propietario  metros propiedad_ocupada  num_cuartos    tipo_prop  \
# 0     Juan Pérez   200.0                 S            3         Casa
# 1    María López     NaN                 S            2  Apartamento
# 2   Carlos Gómez   500.0                 N            4         Casa
# 3  Ana Rodríguez     NaN                 S            1  Apartamento
# 4  Luis Martínez   300.0                 S            5         Casa
#
#     ubicacion  año_construccion valor_prop  num_baños            estado_prop  \
# 0    Alajuela              1995   $250,000        2.0            Buen estado
# 1    San José              2010   $180,000        1.0            Buen estado
# 2     Cartago              1980   $400,000        3.0  Necesita reparaciones
# 3     Heredia              2015   $120,000        1.0            Buen estado
# 4  Guanacaste              2005   $320,000        NaN            Buen estado
#
#   tipo_construccion   servicios_disp comodidades  num_garajes
# 0       Tradicional           Garaje     Terraza          2.0
# 1           Moderna         Gimnasio      Balcón          1.0
# 2       Tradicional           Jardín    Chimenea          3.0
# 3           Moderna  Estacionamiento      Balcón          1.0
# 4       Tradicional           Garaje     Terraza          2.0
# '💡DIMENCION DEL DF: FILAS, COLUMNAS'
# (12, 14)
# '💡tabla de: Columna - sumatoria de valores unicos'
# propietario          12
# metros                6
# propiedad_ocupada     2
# num_cuartos           6
# tipo_prop             2
# ubicacion             7
# año_construccion     12
# valor_prop           12
# num_baños             6
# estado_prop           3
# tipo_construccion     2
# servicios_disp        7
# comodidades           6
# num_garajes           3
# dtype: int64
# '💡 Tabla de: Columna - valores non-null - TDD'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   propietario        12 non-null     object
#  1   metros             6 non-null      float64
#  2   propiedad_ocupada  12 non-null     object
#  3   num_cuartos        12 non-null     int64
#  4   tipo_prop          12 non-null     object
#  5   ubicacion          12 non-null     object
#  6   año_construccion   12 non-null     int64
#  7   valor_prop         12 non-null     object
#  8   num_baños          10 non-null     float64
#  9   estado_prop        12 non-null     object
#  10  tipo_construccion  12 non-null     object
#  11  servicios_disp     12 non-null     object
#  12  comodidades        12 non-null     object
#  13  num_garajes        10 non-null     float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 1.4+ KB
# None
# '💡tabla de info faltante: columna - sumatoria de valores null en esa columna'
# propietario          0
# metros               6
# propiedad_ocupada    0
# num_cuartos          0
# tipo_prop            0
# ubicacion            0
# año_construccion     0
# valor_prop           0
# num_baños            2
# estado_prop          0
# tipo_construccion    0
# servicios_disp       0
# comodidades          0
# num_garajes          2
# dtype: int64
# '💡tabla: Estadistica descriptiva para cada columna numerica del df.'
#           metros  num_cuartos  año_construccion  num_baños  num_garajes
# count    6.00000    12.000000         12.000000  10.000000    10.000000
# mean   375.00000     3.250000       2004.916667   1.900000     1.700000
# std    154.11035     1.422226         11.781791   0.875595     0.823273
# min    200.00000     1.000000       1980.000000   1.000000     1.000000
# 25%    262.50000     2.000000       1998.750000   1.125000     1.000000
# 50%    350.00000     3.000000       2007.500000   1.750000     1.500000
# 75%    475.00000     4.000000       2012.750000   2.375000     2.000000
# max    600.00000     6.000000       2019.000000   3.500000     3.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['metros'].plot(kind='hist', bins=20, title='metros')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['num_cuartos'].plot(kind='hist', bins=20, title='num_cuartos')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['año_construccion'].plot(kind='hist', bins=20, title='año_construccion')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['num_baños'].plot(kind='hist', bins=20, title='num_baños')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='metros', y='num_cuartos', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='num_cuartos', y='año_construccion', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='año_construccion', y='num_baños', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='num_baños', y='num_garajes', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['metros'].plot(kind='line', figsize=(8, 4), title='metros')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['num_cuartos'].plot(kind='line', figsize=(8, 4), title='num_cuartos')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['año_construccion'].plot(kind='line', figsize=(8, 4), title='año_construccion')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['num_baños'].plot(kind='line', figsize=(8, 4), title='num_baños')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# **📊📉📈📇🗓️📅📆Estadistica Descriptiva**
#
# ---

# %%
display("💡Tabla: Estadistica descriptiva para cada columna numérica del df:mean, max, min, std, 25%..., condf.describe() ")
display(df.describe())

display("💡Estadísticas descriptivas para columnas categóricasc, con df.describe(include='object')")
display(df.describe(include='object'))

display("💡Estadísticas descriptivas para TODAS las columnas, con df.describe(include='all')")
display(df.describe(include='all'))
# Out:
# '💡Tabla: Estadistica descriptiva para cada columna numérica del df:mean, max, min, std, 25%..., condf.describe() '
#           metros  num_cuartos  año_construccion  num_baños  num_garajes
# count    6.00000    12.000000         12.000000  10.000000    10.000000
# mean   375.00000     3.250000       2004.916667   1.900000     1.700000
# std    154.11035     1.422226         11.781791   0.875595     0.823273
# min    200.00000     1.000000       1980.000000   1.000000     1.000000
# 25%    262.50000     2.000000       1998.750000   1.125000     1.000000
# 50%    350.00000     3.000000       2007.500000   1.750000     1.500000
# 75%    475.00000     4.000000       2012.750000   2.375000     2.000000
# max    600.00000     6.000000       2019.000000   3.500000     3.000000
# "💡Estadísticas descriptivas para columnas categóricasc, con df.describe(include='object')"
#        propietario propiedad_ocupada tipo_prop ubicacion valor_prop  \
# count           12                12        12        12         12
# unique          12                 2         2         7         12
# top     Juan Pérez                 S      Casa  Alajuela   $250,000
# freq             1                10         6         3          1
#
#         estado_prop tipo_construccion   servicios_disp comodidades
# count            12                12               12          12
# unique            3                 2                7           6
# top     Buen estado       Tradicional  Estacionamiento      Balcón
# freq              9                 6                3           4
# "💡Estadísticas descriptivas para TODAS las columnas, con df.describe(include='all')"
#        propietario     metros propiedad_ocupada  num_cuartos tipo_prop  \
# count           12    6.00000                12    12.000000        12
# unique          12        NaN                 2          NaN         2
# top     Juan Pérez        NaN                 S          NaN      Casa
# freq             1        NaN                10          NaN         6
# mean           NaN  375.00000               NaN     3.250000       NaN
# std            NaN  154.11035               NaN     1.422226       NaN
# min            NaN  200.00000               NaN     1.000000       NaN
# 25%            NaN  262.50000               NaN     2.000000       NaN
# 50%            NaN  350.00000               NaN     3.000000       NaN
# 75%            NaN  475.00000               NaN     4.000000       NaN
# max            NaN  600.00000               NaN     6.000000       NaN
#
#        ubicacion  año_construccion valor_prop  num_baños  estado_prop  \
# count         12         12.000000         12  10.000000           12
# unique         7               NaN         12        NaN            3
# top     Alajuela               NaN   $250,000        NaN  Buen estado
# freq           3               NaN          1        NaN            9
# mean         NaN       2004.916667        NaN   1.900000          NaN
# std          NaN         11.781791        NaN   0.875595          NaN
# min          NaN       1980.000000        NaN   1.000000          NaN
# 25%          NaN       1998.750000        NaN   1.125000          NaN
# 50%          NaN       2007.500000        NaN   1.750000          NaN
# 75%          NaN       2012.750000        NaN   2.375000          NaN
# max          NaN       2019.000000        NaN   3.500000          NaN
#
#        tipo_construccion   servicios_disp comodidades  num_garajes
# count                 12               12          12    10.000000
# unique                 2                7           6          NaN
# top          Tradicional  Estacionamiento      Balcón          NaN
# freq                   6                3           4          NaN
# mean                 NaN              NaN         NaN     1.700000
# std                  NaN              NaN         NaN     0.823273
# min                  NaN              NaN         NaN     1.000000
# 25%                  NaN              NaN         NaN     1.000000
# 50%                  NaN              NaN         NaN     1.500000
# 75%                  NaN              NaN         NaN     2.000000
# max                  NaN              NaN         NaN     3.000000

# %% [markdown]
# **📊📉📈📇🗓️📅📆Estadistica Descriptiva: La media o promedio, mediana y moda**

# %%
tabla_col_numericos = df[["metros", "num_cuartos", "año_construccion", "num_baños", "num_garajes"]]
media = tabla_col_numericos.mean().round(2)
display("💡Estadísticas descriptivas: PROMEDIO")
display(media)
# Out:
# '💡Estadísticas descriptivas: PROMEDIO'
# metros               375.00
# num_cuartos            3.25
# año_construccion    2004.92
# num_baños              1.90
# num_garajes            1.70
# dtype: float64
